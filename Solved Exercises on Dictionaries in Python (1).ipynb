# %%
# PART A
person_info = {
    "name": "John Doe",
    "age": 30,
    "city": "New York",
    "hobbies": ["traveling"]
}

# PART B
def word_frequency(text):
    
    # Create a dictionary to store word counts
    word_count = {}
    
    # Loop through each word and count its frequency
    for word in words:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1
    
    return word_count

# Example usage
text = input("Enter the text: ")

# Call the word_frequency function
word_count = word_frequency(text)

# Display the word count
print("Word Frequency Count:")
for word, count in word_count.items():
    print(f"'{word}': {count}")
            # PART C
inventory = {
    "apples": 50,
    "bananas": 30,
    "oranges": 20,
    "grapes": 15
}
inventory["mangoes"] = 25
inventory["bananas"] -= 5
print(inventory)
item = "oranges"
if item in inventory:
    print(f"Inventory for {item}: {inventory[item]}")
else:
    print(f"{item} not found in the inventory.")

    # PART D
orders = [
    {"customer_id": 1, "product": "laptop", "category": "electronics"},
    {"customer_id": 2, "product": "phone", "category": "electronics"},
    {"customer_id": 3, "product": "shirt", "category": "clothing"},
    {"customer_id": 4, "product": "headphones", "category": "electronics"}
]
category_count = {}
for order in orders:
    category = order["category"]
    if category in category_count:
        category_count[category] += 1
    else:
        category_count[category] = 1
most_popular_category = max(category_count, key=category_count.get)
print(f"The most popular category is: {most_popular_category}")
 
#PART E
rades = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78
}
total_grades = sum(grades.values())
average_grade = total_grades / len(grades)
print(f"The average grade is: {average_grade:.2f}")

#PART F
inventory = {
    "laptop": {"quantity": 10, "price": 800},
    "phone": {"quantity": 25, "price": 600},
    "headphones": {"quantity": 15, "price": 150},
    "keyboard": {"quantity": 30, "price": 50}
}
add_product("tablet", 20, 400)
# Add a new product
add_product("tablet", 20, 400)
# Update the quantity of an existing product
update_quantity("laptop", 5)
# Calculate total inventory value
total_value = total_inventory_value()
print(f"Total inventory value: ${total_value:.2f}")
# Generate a low-stock report (default threshold is 10)
low_stock = low_stock_report()
print("Low-stock items:")
for product, details in low_stock.items():
    print(f"{product}: {details['quantity']} units left, ${details['price']} each")
    
# PART G
students = {
    "Alice": {"math": 85, "science": 92, "english": 78},
    "Bob": {"math": 90, "science": 80, "english": 88},
    "Charlie": {"math": 70, "science": 75, "english": 80},
    "David": {"math": 95, "science": 91, "english": 89},
    "Eva": {"math": 88, "science": 84, "english": 93}
}

# Function to calculate the average grade for each student
def calculate_average(grades):
    return sum(grades.values()) / len(grades)

# Function to find the highest and lowest grades in a specific subject
def find_highest_and_lowest(subject):
    highest_grade = -float('inf')
    lowest_grade = float('inf')
    highest_student = ""
    lowest_student = ""
    
    for student, grades in students.items():
        if subject in grades:
            grade = grades[subject]
            if grade > highest_grade:
                highest_grade = grade
                highest_student = student
            if grade < lowest_grade:
                lowest_grade = grade
                lowest_student = student
    
    return highest_student, highest_grade, lowest_student, lowest_grade

# Function to sort students by their average grades
def sort_students_by_average():
    student_averages = {}
    for student, grades in students.items():
        student_averages[student] = calculate_average(grades)
    
    # Sort the students by average grade in descending order
    sorted_students = sorted(student_averages.items())
    return sorted_students

# Calculate the average grade for each student and display it
print("Student Average Grades:")
for student, grades in students.items():
    avg_grade = calculate_average(grades)
    print(f"{student}: {avg_grade:.2f}")

# Find the highest and lowest grades in a specific subject (e.g., "math")
subject = "math"
highest_student, highest_grade, lowest_student, lowest_grade = find_highest_and_lowest(subject)
print(f"\nHighest grade in {subject}: {highest_student} with {highest_grade}")
print(f"Lowest grade in {subject}: {lowest_student} with {lowest_grade}")

# Sort students by average grade and display the result
sorted_students = sort_students_by_average()
print("\nStudents sorted by average grade:")
for student, avg_grade in sorted_students:
    print(f"{student}: {avg_grade:.2f}")
    
# PART H
products = {
    "laptop": {"price": 800, "quantity": 10},
    "phone": {"price": 600, "quantity": 20},
    "headphones": {"price": 150, "quantity": 50},
    "keyboard": {"price": 50, "quantity": 30}
}


# Add items to the cart
add_to_cart("laptop", 2)
add_to_cart("phone", 1)
add_to_cart("headphones", 3)

# Calculate the total cost of the cart
total_cost = calculate_total()
print(f"Total cost before discount and tax: ${total_cost:.2f}")

# Apply a 10% discount
total_cost_with_discount = apply_discount(total_cost, 10)
print(f"Total cost after 10% discount: ${total_cost_with_discount:.2f}")

# Apply a 5% tax
total_cost_with_tax = apply_tax(total_cost_with_discount, 5)
print(f"Total cost after 5% tax: ${total_cost_with_tax:.2f}")

# Remove items from the cart
remove_from_cart("phone", 1)

# Calculate the new total cost after removing an item
new_total_cost = calculate_total()
print(f"New total cost after removing items: ${new_total_cost:.2f}")
